# %%
#!pip install PennyLane
#!pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cpu
# Out:
# Collecting PennyLane
#   Using cached PennyLane-0.28.0-py3-none-any.whl (1.3 MB)
# Collecting pennylane-lightning>=0.28
#   Downloading PennyLane_Lightning-0.28.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 1.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: networkx in /home/v/anaconda3/lib/python3.9/site-packages (from PennyLane) (2.8.4)
# Collecting autograd
#   Using cached autograd-1.5-py3-none-any.whl (48 kB)
# Requirement already satisfied: toml in /home/v/anaconda3/lib/python3.9/site-packages (from PennyLane) (0.10.2)
# Requirement already satisfied: appdirs in /home/v/anaconda3/lib/python3.9/site-packages (from PennyLane) (1.4.4)
# Requirement already satisfied: cachetools in /home/v/anaconda3/lib/python3.9/site-packages (from PennyLane) (5.3.0)
# Collecting retworkx
#   Using cached retworkx-0.12.1-py3-none-any.whl (10 kB)
# Collecting autoray>=0.3.1
#   Using cached autoray-0.6.0-py3-none-any.whl (46 kB)
# Collecting semantic-version>=2.7
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy<1.24 in /home/v/anaconda3/lib/python3.9/site-packages (from PennyLane) (1.21.5)
# Requirement already satisfied: requests in /home/v/anaconda3/lib/python3.9/site-packages (from PennyLane) (2.28.1)
# Requirement already satisfied: scipy in /home/v/anaconda3/lib/python3.9/site-packages (from PennyLane) (1.9.1)
# Collecting ninja
#   Using cached ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
# Requirement already satisfied: future>=0.15.2 in /home/v/anaconda3/lib/python3.9/site-packages (from autograd->PennyLane) (0.18.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/v/anaconda3/lib/python3.9/site-packages (from requests->PennyLane) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/v/anaconda3/lib/python3.9/site-packages (from requests->PennyLane) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/v/anaconda3/lib/python3.9/site-packages (from requests->PennyLane) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/v/anaconda3/lib/python3.9/site-packages (from requests->PennyLane) (3.3)
# Collecting rustworkx==0.12.1
#   Downloading rustworkx-0.12.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: ninja, semantic-version, rustworkx, autoray, autograd, retworkx, pennylane-lightning, PennyLane
# Successfully installed PennyLane-0.28.0 autograd-1.5 autoray-0.6.0 ninja-1.11.1 pennylane-lightning-0.28.2 retworkx-0.12.1 rustworkx-0.12.1 semantic-version-2.10.0

# %%
#from sympy import conjugate
from torch.autograd import Variable
import torch
from rsvg import rsvg
import pennylane as qml
import matplotlib.pyplot as plt
import numpy as np
from tools import *
import sys
import pickle
import os

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-1.13.1%2Bcpu-cp39-cp39-linux_x86_64.whl (199.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.14.1%2Bcpu-cp39-cp39-linux_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 8.4 MB/s eta 0:00:000m eta 0:00:010:011m
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-0.13.1%2Bcpu-cp39-cp39-linux_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 8.1 MB/s eta 0:00:000m eta 0:00:010:00:01
# Requirement already satisfied: typing-extensions in /home/v/anaconda3/lib/python3.9/site-packages (from torch) (4.3.0)
# Requirement already satisfied: requests in /home/v/anaconda3/lib/python3.9/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: numpy in /home/v/anaconda3/lib/python3.9/site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/v/anaconda3/lib/python3.9/site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/v/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/v/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/v/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/v/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (3.3)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.13.1+cpu torchaudio-0.13.1+cpu torchvision-0.14.1+cpu

# %% [markdown]
# ### Abaixo é as 4 celulas que foram usadas para gerar o gráfico

# %%
n = 100
n_qubits = 1
fidelidades = []
for i in range(0, n):
    circuit, params = vqa(n_qubits)
    target_vector, target_op = init_state_rsvg(n_qubits)
    best_params, f = train(60, circuit, params, target_op)
    fidelidades.append(f[-1])
    with open('Fidelidades_nqb-1.pkl', 'wb') as a:
        pickle.dump(fidelidades, a)
# Out:
# 59 0.0
# 59 9.5367431640625e-07
# 59 1.232595164407831e-32
# 59 0.000186920166015625
# 59 0.00027561187744140994
# 59 8.583068847654949e-06
# 59 0.0
# 59 4.930380657631324e-32
# 59 1.52587890625e-05
# 59 9.536743164058163e-07
# 59 9.536743164058163e-07
# 59 0.0
# 59 1.52587890625e-05
# 59 8.58306884765625e-06
# 59 7.724761962890625e-05
# 59 9.536743164062717e-05
# 59 3.8146972656241326e-06
# 59 9.5367431640625e-07
# 59 1.52587890625e-05
# 59 4.673004150390777e-05
# 59 0.00018692016601562804
# 59 8.58306884765625e-06
# 59 9.5367431640625e-07
# 59 4.673004150390777e-05
# 59 3.814697265625e-06
# 59 9.5367431640625e-07
# 59 4.673004150390777e-05
# 59 2.3841857910157334e-05
# 59 1.5258789062500867e-05
# 59 1.52587890625e-05
# 59 3.814697265625e-06
# 59 0.00011539459228515148
# 59 8.5830688476569e-06
# 59 8.58306884765625e-06
# 59 0.0001611709594726506
# 59 1.52587890625e-05
# 59 1.232595164407831e-32
# 59 3.814697265626301e-06
# 59 1.5258789062498265e-05
# 59 1.5258789062498265e-05
# 59 8.58306884765625e-06
# 59 9.536743164064668e-07
# 59 1.232595164407831e-32
# 59 8.5830688476569e-06
# 59 1.232595164407831e-32
# 59 0.0001373291015625
# 59 0.00021457672119140625
# 59 8.58306884765625e-06
# 59 8.58306884765625e-06
# 59 3.814697265625e-06
# 59 9.536743164064668e-07
# 59 9.536743164062717e-05
# 59 6.103515625000173e-05
# 59 1.52587890625e-05
# 59 1.5258789062500867e-05
# 59 7.724761962890625e-05
# 59 8.5830688476569e-06
# 59 1.52587890625e-05
# 59 9.5367431640625e-07
# 59 0.0
# 59 3.814697265625434e-06
# 59 7.724761962890625e-05
# 59 3.4332275390625e-05
# 59 9.5367431640625e-05
# 59 0.0
# 59 0.0
# 59 3.4332275390625e-05
# 59 1.232595164407831e-32
# 59 9.536743164064668e-07
# 59 9.5367431640625e-07
# 59 1.232595164407831e-32
# 59 2.384185791015408e-05
# 59 0.00011539459228515148
# 59 0.0
# 59 2.3841857910157334e-05
# 59 0.00016117095947265625
# 59 0.0
# 59 0.0
# 59 8.58306884765625e-06
# 59 3.814697265625e-06
# 59 9.536743164058163e-07
# 59 3.814697265625e-06
# 59 8.58306884765625e-06
# 59 3.4332275390625e-05
# 59 6.103515625000173e-05
# 59 6.103515624999653e-05
# 59 3.43322753906263e-05
# 59 3.4332275390625e-05
# 59 3.814697265625e-06
# 59 8.58306884765625e-06
# 59 0.0
# 59 3.4332275390625e-05
# 59 9.5367431640625e-05
# 59 3.8146972656241326e-06
# 59 3.814697265625e-06
# 59 4.930380657631324e-32
# 59 8.5830688476569e-06
# 59 3.43322753906263e-05
# 59 3.814697265625434e-06
# 59 1.232595164407831e-32

# %%
n = 100
n_qubits = 2
fidelidades = []
for i in range(0, n):
    circuit, params = vqa(n_qubits)
    target_vector, target_op = init_state_rsvg(n_qubits)
    best_params, f = train(60, circuit, params, target_op)
    fidelidades.append(f[-1])
    with open('Fidelidades_nqb-2.pkl', 'wb') as a:
        pickle.dump(fidelidades, a)
# Out:
# 59 9.536743164058163e-07
# 59 3.814697265625434e-06
# 59 9.536743164058163e-07
# 59 9.536743164058163e-07
# 59 0.0001373291015624948
# 59 2.3841857910157334e-05
# 59 8.5830688476569e-06
# 59 4.673004150390625e-05
# 59 3.43322753906263e-05
# 59 4.673004150390625e-05
# 59 1.52587890625e-05
# 59 3.43322753906263e-05
# 59 3.4332275390625e-05
# 59 8.5830688476569e-06
# 59 2.384185791015408e-05
# 59 8.58306884765625e-06
# 59 1.525878906249653e-05
# 59 6.103515625e-05
# 59 8.58306884765625e-06
# 59 9.536743164062717e-05
# 59 0.0003814697265625
# 59 9.536743164062717e-05
# 59 3.8146972656241326e-06
# 59 8.58306884765625e-06
# 59 9.536743164062066e-05
# 59 4.930380657631324e-32
# 59 6.103515625000173e-05
# 59 2.384185791015625e-05
# 59 3.8146972656241326e-06
# 59 1.5258789062498265e-05
# 59 0.00011539459228516102
# 59 1.5258789062500867e-05
# 59 1.232595164407831e-32
# 59 3.814697265625e-06
# 59 9.536743164058163e-07
# 59 4.673004150390625e-05
# 59 3.814697265625e-06
# 59 7.724761962890625e-05
# 59 2.3841857910157334e-05
# 59 6.103515624999653e-05
# 59 0.000186920166015625
# 59 0.0
# 59 3.43322753906224e-05
# 59 0.00011539459228515625
# 59 8.58306884765625e-06
# 59 1.5258789062500867e-05
# 59 3.814697265625e-06
# 59 8.58306884765625e-06
# 59 1.5258789062498265e-05
# 59 3.43322753906276e-05
# 59 3.8146972656241326e-06
# 59 7.724761962890625e-05
# 59 4.6730041503903214e-05
# 59 4.930380657631324e-32
# 59 1.232595164407831e-32
# 59 3.4332275390625e-05
# 59 1.52587890625e-05
# 59 3.814697265625e-06
# 59 2.384185791015625e-05
# 59 1.5258789062498265e-05
# 59 2.384185791015625e-05
# 59 3.43322753906263e-05
# 59 2.3841857910157334e-05
# 59 9.536743164064668e-07
# 59 3.4332275390625e-05
# 59 9.5367431640625e-05
# 59 4.673004150390777e-05
# 59 8.583068847658202e-06
# 59 2.384185791015625e-05
# 59 1.5258789062498265e-05
# 59 2.3841857910157334e-05
# 59 6.103515625e-05
# 59 9.536743164064668e-07
# 59 2.3841857910157334e-05
# 59 8.583068847654949e-06
# 59 0.0001373291015625078
# 59 7.72476196289082e-05
# 59 2.3841857910157334e-05
# 59 8.583068847654949e-06
# 59 9.5367431640625e-07
# 59 2.384185791015625e-05
# 59 4.930380657631324e-32
# 59 7.724761962890625e-05
# 59 9.536743164058163e-07
# 59 4.673004150390777e-05
# 59 3.814697265625434e-06
# 59 1.5258789062500867e-05
# 59 1.232595164407831e-32
# 59 0.00018692016601561893
# 59 1.52587890625e-05
# 59 2.3841857910157334e-05
# 59 0.0001373291015624948
# 59 9.536743164062717e-05
# 59 3.43322753906263e-05
# 59 2.384185791015625e-05
# 59 1.232595164407831e-32
# 59 1.5258789062498265e-05
# 59 9.536743164062066e-05
# 59 0.0
# 59 9.536743164062066e-05

# %%
n = 100
n_qubits = 3
fidelidades = []
for i in range(0, n):
    circuit, params = vqa(n_qubits)
    target_vector, target_op = init_state_rsvg(n_qubits)
    best_params, f = train(60, circuit, params, target_op)
    fidelidades.append(f[-1])
    with open('Fidelidades_nqb-3.pkl', 'wb') as a:
        pickle.dump(fidelidades, a)
# Out:
# 59 0.00011539459228515148
# 59 6.103515625e-05
# 59 2.3841857910157334e-05
# 59 9.536743164062066e-05
# 59 3.4332275390625e-05
# 59 9.536743164062717e-05
# 59 3.814697265625434e-06
# 59 0.0001373291015625026
# 59 9.5367431640625e-05
# 59 2.3841857910157334e-05
# 59 7.72476196289082e-05
# 59 9.536743164062066e-05
# 59 4.673004150390625e-05
# 59 0.0001373291015624896
# 59 3.43322753906263e-05
# 59 6.103515625000173e-05
# 59 6.103515624999653e-05
# 59 0.00011539459228515625
# 59 3.4332275390625e-05
# 59 0.00018692016601562804
# 59 3.814697265625434e-06
# 59 7.724761962890625e-05
# 59 2.3841857910157334e-05
# 59 3.43322753906224e-05
# 59 6.103515624999653e-05
# 59 3.43322753906289e-05
# 59 4.673004150390777e-05
# 59 6.103515624999653e-05
# 59 0.00011539459228515625
# 59 0.0001373291015624948
# 59 9.536743164062717e-05
# 59 3.43322753906224e-05
# 59 9.5367431640625e-05
# 59 9.536743164062717e-05
# 59 6.103515624999653e-05
# 59 8.58306884765625e-06
# 59 3.43322753906263e-05
# 59 3.43322753906289e-05
# 59 4.673004150390777e-05
# 59 4.673004150390777e-05
# 59 7.724761962890625e-05
# 59 0.0001373291015625
# 59 7.72476196289082e-05
# 59 6.103515625e-05
# 59 7.724761962890235e-05
# 59 2.384185791015625e-05
# 59 3.814697265625434e-06
# 59 3.43322753906263e-05
# 59 6.103515625000173e-05
# 59 0.00021457672119140625
# 59 0.00011539459228515625
# 59 0.00011539459228515864
# 59 6.103515625e-05
# 59 0.0001373291015624948
# 59 0.0001611709594726506
# 59 4.6730041503903214e-05
# 59 0.0001373291015625
# 59 3.43322753906263e-05
# 59 3.814697265626301e-06
# 59 0.0001373291015624948
# 59 9.536743164062717e-05
# 59 7.72476196289082e-05
# 59 4.673004150390777e-05
# 59 6.103515624999653e-05
# 59 6.103515625000173e-05
# 59 0.00016117095947264497
# 59 0.0001611709594726506
# 59 3.43322753906224e-05
# 59 6.103515625000173e-05
# 59 8.583068847654949e-06
# 59 3.43322753906263e-05
# 59 6.103515624999653e-05
# 59 0.0001373291015624948
# 59 8.58306884765625e-06
# 59 0.00011539459228515864
# 59 6.103515625e-05
# 59 4.673004150390625e-05
# 59 3.814697265625e-06
# 59 9.5367431640625e-07
# 59 3.8146972656241326e-06
# 59 7.72476196289082e-05
# 59 7.72476196289082e-05
# 59 1.5258789062498265e-05
# 59 7.724761962890625e-05
# 59 0.0001153945922851634
# 59 0.00016117095947265625
# 59 7.72476196289082e-05
# 59 1.52587890625e-05
# 59 4.673004150390777e-05
# 59 0.00027561187744140625
# 59 3.43322753906263e-05
# 59 3.43322753906224e-05
# 59 2.384185791015625e-05
# 59 0.00021457672119139974
# 59 4.673004150390777e-05
# 59 4.673004150390777e-05
# 59 3.43322753906224e-05
# 59 9.5367431640625e-07
# 59 9.5367431640625e-05
# 59 3.814697265625e-06

# %%
n_qubits = 4
n = 100
fidelidades = []

for i in range(0, n):
    print(f'n = {i}')
    circuit, params = vqa(n_qubits)
    target_vector, target_op = init_state_rsvg(n_qubits)
    best_params, f = train(60, circuit, params, target_op)
    fidelidades.append(f[-1])
    with open('Fidelidades_nqb-4.pkl', 'wb') as a:
        pickle.dump(fidelidades, a)

os.system("shutdown now -h")
# Out:
# n = 0
# 59 0.00018692016601561286
# n = 1
# 59 0.0001611709594726506
# n = 2
# 59 0.00011539459228514671
# n = 3
# 59 0.0003814697265625
# n = 4
# 59 0.0001373291015625
# n = 5
# 59 4.6730041503903214e-05
# n = 6
# 59 0.0001373291015625026
# n = 7
# 59 7.72476196289082e-05
# n = 8
# 59 0.000644683837890625
# n = 9
# 59 0.0003442764282226686
# n = 10
# 59 0.0009164810180663928
# n = 11
# 59 0.000308990478515625
# n = 12
# 59 4.673004150390777e-05
# n = 13
# 59 0.00024414062499999306
# n = 14
# 59 9.536743164062717e-05
# n = 15
# 59 0.0001611709594726506
# n = 16
# 59 9.536743164062717e-05
# n = 17
# 59 0.000186920166015625
# n = 18
# 59 0.000461578369140625
# n = 19
# 59 0.0001373291015625
# n = 20
# 59 0.000186920166015625
# n = 21
# 59 0.000461578369140625
# n = 22
# 59 4.673004150390777e-05
# n = 23
# 59 8.58306884765625e-06
# n = 24
# 59 7.72476196289082e-05
# n = 25
# 59 6.103515625000173e-05
# n = 26
# 59 0.00046157836914062977
# n = 27
# 59 0.00021457672119140625
# n = 28
# 59 0.0002756118774413915
# n = 29
# 59 0.0001373291015625
# n = 30
# 59 4.673004150391232e-05
# n = 31
# 59 6.103515625e-05
# n = 32
# 59 0.0004205703735351608
# n = 33
# 59 0.00034427642822265625
# n = 34
# 59 6.103515624999306e-05
# n = 35
# 59 0.00024414062499999306
# n = 36
# 59 0.00011539459228515864
# n = 37
# 59 9.5367431640625e-05
# n = 38
# 59 4.6730041503903214e-05
# n = 39
# 59 9.536743164062717e-05
# n = 40
# 59 0.00034427642822266037
# n = 41
# 59 9.536743164062066e-05
# n = 42
# 59 0.00011539459228515625
# n = 43
# 59 0.00016117095947265625
# n = 44
# 59 0.0001373291015624896
# n = 45
# 59 0.00034427642822266037
# n = 46
# 59 0.0003814697265624913
# n = 47
# 59 7.724761962889844e-05
# n = 48
# 59 0.00011539459228515148
# n = 49
# 59 9.5367431640625e-05
# n = 50
# 59 0.00021457672119140625
# n = 51
# 59 4.6730041503903214e-05
# n = 52
# 59 0.00011539459228516579
# n = 53
# 59 0.0003089904785156289
# n = 54
# 59 0.00011539459228515625
# n = 55
# 59 0.0003089904785156289
# n = 56
# 59 0.0003089904785156172
# n = 57
# 59 0.00018692016601562804
# n = 58
# 59 0.00021457672119140625
# n = 59
# 59 4.6730041503903214e-05
# n = 60
# 59 9.536743164062717e-05
# n = 61

# %%
files =['Fidelidades_nqb-1.pkl', 'Fidelidades_nqb-2.pkl', 'Fidelidades_nqb-3.pkl', 'Fidelidades_nqb-4.pkl']
with open(files[0], 'rb') as f:
    y1 = pickle.load(f)
with open(files[1], 'rb') as f:
    y2 = pickle.load(f)
with open(files[2], 'rb') as f:
    y3 = pickle.load(f)
with open(files[3], 'rb') as f:
    y4 = pickle.load(f)

size = 100
x = np.linspace(1, size, size)
plt.plot(x, y1[0:size], label='1 Qubit', linestyle="dashdot")
plt.plot(x, y2[0:size], label='2 Qubit', linestyle=":")
plt.plot(x, y3[0:size], label='3 Qubit', linestyle="--")
plt.plot(x, y4[0:size], label='4 Qubit')
plt.title('Fidelidade dos estados preparados')
plt.ylim(0.95, 1.01)
plt.legend()
plt.show()

# %%
x = np.linspace(1,4,4)
fids = []
fids.append(sum(y1)/len(y1))
fids.append(sum(y2)/len(y2))
fids.append(sum(y3)/len(y3))
fids.append(sum(y4)/len(y4))
#x = np.linspace(0,len(fidelidades),len(fidelidades))
plt.plot(x,fids,label='Fidelidade média')
plt.title('Média de 100 estados')
plt.xlabel('n_qubits')
plt.ylabel('Fidelidade média')
#plt.ylim(0.5,1)
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# # ----------------------------------------------

# %% [markdown]
# ### Abaixo é a comparação de dois modelos diferentes para treinar um VQA para preparação de um estado de 4 qubits

# %%
n_qubits = 4
fidelidades = []

circuit, params = vqa_extra_cnot_depth5(n_qubits)
target_vector, target_op = init_state_rsvg(n_qubits)
#fig, ax = qml.draw_mpl(circuit, decimals=2)(params, target_op)
#plt.show()
best_params, f_extra_cnot, loss1 = train2(70, circuit, params, target_op)

circuit, params = vqa(n_qubits)
target_vector, target_op = init_state_rsvg(n_qubits)
#fig, ax = qml.draw_mpl(circuit, decimals=2)(params, target_op)
#plt.show()
best_params, f, loss_extra = train2(70, circuit, params, target_op)
# Out:
# 69 0.000976562500000007
# 69 3.43322753906224e-05

# %%
size = 70
x = np.linspace(0, size, size)

plt.plot(x, f,'b', label='fidelidade circuit 1', linestyle="dashdot")
plt.plot(x, loss1,'b', label='loss 1', linestyle="-")
plt.plot(x, f_extra_cnot,'g', label='fidelidade circuit 2', linestyle="dashdot")
plt.plot(x, loss_extra,'g', label='loss 2', linestyle="-")
plt.title('Loss e Fidelidade em função das épocas')
plt.ylim(0, 1.01)
plt.legend()
plt.show()

# %%
n_qubits = 4
n = 1
fidelidades = []

for i in range(0, n):
    print(f'n = {i}')
    circuit, params = vqa_extra_cnot(n_qubits)
    target_vector, target_op = init_state_rsvg(n_qubits)
    best_params, f = train(35, circuit, params, target_op)
    fidelidades.append(f[-1])
    with open('Fidelidades_nqb-4_extra_cnot.pkl', 'wb') as a:
        pickle.dump(fidelidades, a)
# Out:
# n = 0
# 0 0.6793365478515625
# 1 0.5639657974243164
# 2 0.3992166519165039
# 3 0.29587650299072266
# 4 0.23937320709228516
# 5 0.14505386352539062
# 6 0.16109561920166016
# 7 0.13126468658447266
# 8 0.1121988296508789
# 9 0.07800674438476562
# 10 0.0625
# 11 0.06747817993164062
# 12 0.050449371337890625
# 13 0.0841226577758789
# 14 0.0644683837890625
# 15 0.08525943756103516
# 16 0.07212162017822266
# 17 0.08020401000976562
# 18 0.0710763931274414
# 19 0.06747817993164062
# 20 0.0669717788696289
# 21 0.047425270080566406
# 22 0.04449462890625
# 23 0.037011146545410156
# 24 0.036263465881347656
# 25 0.034427642822265625
# 26 0.029541015625
# 27 0.023807525634765625
# 28 0.028873443603515625
# 29 0.022912025451660156
# 30 0.023807525634765625
# 31 0.021744728088378906
# 32 0.015870094299316406
# 33 0.021172523498535156
# 34 0.014428138732910156
# 34 0.014428138732910156

# %%
with open('Fidelidades_nqb-4.pkl', 'rb') as f:
    fidelidades = pickle.load(f)
len(fidelidades)
# Out:
# 38

# %%
import pennylane as qml
import matplotlib.pyplot as plt
import numpy as np
from tools import *
import sys
import pickle
#n_qubits = 1
n = 1
x = []
y1 = []
y2 = []


fide = []
fidelidades = []
for n_qubits in range(1, 5):
    for i in range(0, n):
        for depht in range(1,7):

            print(f' n = {i}, depht = {depht}')
            circuit, params = vqa(n_qubits,depht)
            target_vector, target_op = init_state_rsvg(n_qubits)
            best_params, f , loss = train2(1, circuit, params, target_op)
            print(max(f))
            fide.append(max(f))
    fidelidades.append(fide)
#   
#    x.append(n_qubits)
#    y1.append(fid_med)
#    y2.append(var)
#
#    print(f'variancia = {np.var(fidelidades)}')
#    print(f'fid_med = {fid_med}')
#
#print(x)
#print(y1)
#print(y2)
# Out:
#  n = 0, depht = 1
# 0.056640625000000014
#  n = 0, depht = 2
# 0.5185546875000001
#  n = 0, depht = 3
# 0.6044921875
#  n = 0, depht = 4
# 0.3740234375
#  n = 0, depht = 5
# 0.333984375
#  n = 0, depht = 6
# 0.7353515625
#  n = 0, depht = 1
# 0.18359375
#  n = 0, depht = 2
# 0.30078125
#  n = 0, depht = 3
# 0.8466796875
#  n = 0, depht = 4
# 0.501953125
#  n = 0, depht = 5
# 0.06152343750000002
#  n = 0, depht = 6
# 0.10449218750000003
#  n = 0, depht = 1
# 0.5693359375
#  n = 0, depht = 2
# 0.06054687500000003
#  n = 0, depht = 3
# 0.2656250000000001
#  n = 0, depht = 4
# 0.4179687500000001
#  n = 0, depht = 5
# 0.4648437499999999
#  n = 0, depht = 6
# 0.5800781249999998
#  n = 0, depht = 1
# 0.04687499999999997
#  n = 0, depht = 2
# 0.28515625
#  n = 0, depht = 3
# 0.0869140625
#  n = 0, depht = 4
# 0.4462890624999999
#  n = 0, depht = 5
# 0.3974609375000001
#  n = 0, depht = 6
# 0.32421875

# %%
print(fidelidades)
print(len(fidelidades[0]))
x = np.linspace(1,5,5)
y1 = fidelidades[0]
y2 = fidelidades[1]
y3 = fidelidades[2]
y4 = fidelidades[3]


plt.plot(x, y1, label='depht = 1')
plt.plot(x, y2, label='depht = 2')
plt.plot(x, y3, label='depht = 3')
plt.plot(x, y4, label='depht = 3fid_med')
plt.legend()
plt.show()
# Out:
# [[0.056640625000000014, 0.5185546875000001, 0.6044921875, 0.3740234375, 0.333984375, 0.7353515625, 0.18359375, 0.30078125, 0.8466796875, 0.501953125, 0.06152343750000002, 0.10449218750000003, 0.5693359375, 0.06054687500000003, 0.2656250000000001, 0.4179687500000001, 0.4648437499999999, 0.5800781249999998, 0.04687499999999997, 0.28515625, 0.0869140625, 0.4462890624999999, 0.3974609375000001, 0.32421875], [0.056640625000000014, 0.5185546875000001, 0.6044921875, 0.3740234375, 0.333984375, 0.7353515625, 0.18359375, 0.30078125, 0.8466796875, 0.501953125, 0.06152343750000002, 0.10449218750000003, 0.5693359375, 0.06054687500000003, 0.2656250000000001, 0.4179687500000001, 0.4648437499999999, 0.5800781249999998, 0.04687499999999997, 0.28515625, 0.0869140625, 0.4462890624999999, 0.3974609375000001, 0.32421875], [0.056640625000000014, 0.5185546875000001, 0.6044921875, 0.3740234375, 0.333984375, 0.7353515625, 0.18359375, 0.30078125, 0.8466796875, 0.501953125, 0.06152343750000002, 0.10449218750000003, 0.5693359375, 0.06054687500000003, 0.2656250000000001, 0.4179687500000001, 0.4648437499999999, 0.5800781249999998, 0.04687499999999997, 0.28515625, 0.0869140625, 0.4462890624999999, 0.3974609375000001, 0.32421875], [0.056640625000000014, 0.5185546875000001, 0.6044921875, 0.3740234375, 0.333984375, 0.7353515625, 0.18359375, 0.30078125, 0.8466796875, 0.501953125, 0.06152343750000002, 0.10449218750000003, 0.5693359375, 0.06054687500000003, 0.2656250000000001, 0.4179687500000001, 0.4648437499999999, 0.5800781249999998, 0.04687499999999997, 0.28515625, 0.0869140625, 0.4462890624999999, 0.3974609375000001, 0.32421875]]
# 24
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_86900/1822195618.py in <module>
#       8
#       9
# ---> 10 plt.plot(x, y1, label='depht = 1')
#      11 plt.plot(x, y2, label='depht = 2')
#      12 plt.plot(x, y3, label='depht = 3')
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (5,) and (24,)

# %%
with open('Fidelidades_nqb-4.pkl', 'rb') as f:
    mynewlist = pickle.load(f)
mynewlist
# Out:
# [0.2734375000000002, 0.396484375]

# %%
fidelidades = []
n_examples = 10
x = []
for m in range(1,5):
    x.append(m)
    fid = 0
    n_qubits = m
    depht = n_qubits + 1
    n = 3*n_qubits*(1+depht)
    for _ in range(n_examples):
        target_vector, alpha = init_state_rsvg(n_qubits)
        params = random_params(n)
        device = get_device(n_qubits)
        @qml.qnode(device, interface="torch")
        def circuit(params, M=None):
            w = []
            aux = 0
            for j in range(n_qubits):
                qml.RX(params[j+aux], wires=j)
                qml.RY(params[j+1+aux], wires=j)
                qml.RZ(params[j+2+aux], wires=j)
                w.append(j)
                aux+=2
            for z in range(depht):
                for i in range(n_qubits-1):
                    qml.CNOT(wires=[i,i+1])
                for j in range(n_qubits):
                    qml.RX(params[j+aux], wires=j)
                    qml.RY(params[j+1+aux], wires=j)
                    qml.RZ(params[j+2+aux], wires=j)
                    aux+=2
            return qml.expval(qml.Hermitian(M, wires=w))
        best_params, f = train(60, circuit, params, alpha)
        fid += fidelidade(circuit, best_params, alpha)
    fidelidades.append(fid/n_examples)
#x = np.linspace(0,len(fidelidades),len(fidelidades))
plt.plot(x,fidelidades)
plt.title('depth = n_qubits + 1')
print('Fidelidade = ',fidelidade(circuit, best_params, alpha))
plt.xlabel('n_qubits')
plt.ylabel('Fidelidade média')
plt.show()
#fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
#plt.show()
# Out:
# [1]
# 59 1.232595164407831e-32
# 59 0.00016117095947265907
# 59 4.930380657631324e-32
# 59 0.00011539459228515864
# 59 1.52587890625e-05
# 59 8.58306884765625e-06
# 59 0.0
# 59 4.673004150390625e-05
# 59 0.0
# 59 1.5258789062498265e-05
# [1, 2]
# 59 2.384185791015408e-05
# 59 3.4332275390625e-05
# 59 4.6730041503903214e-05
# 59 0.0
# 59 3.43322753906224e-05
# 59 3.43322753906263e-05
# 59 7.72476196289082e-05
# 59 3.8146972656241326e-06
# 59 3.814697265626301e-06
# 59 2.384185791015625e-05
# [1, 2, 3]
# 59 0.00024414062499999306
# 59 8.58306884765625e-06
# 59 1.525878906249653e-05
# 59 6.103515624999653e-05
# 59 3.814697265625434e-06
# 59 0.00021457672119139324
# 59 8.583068847654949e-06
# 59 9.536743164062717e-05
# 59 0.00016117095947265907
# 59 1.5258789062498265e-05
# [1, 2, 3, 4]
# 59 9.5367431640625e-05
# 59 6.103515624999653e-05
# 59 0.00027561187744140625
# 59 0.00021457672119139974
# 59 7.724761962890235e-05
# 59 0.000186920166015625
# 59 0.0001373291015625
# 59 0.000344276428222648
# 59 0.0003089904785156172
# 59 0.00011539459228515864
# Fidelidade =  0.9833984374999999

# %% [markdown]
# # to do
# * calcular a variancia de cada estado preparado.
# * escrever no documento os resultados obtidos até agora.

# %%
for m in range(1,4):
    for p in range(4):
        n_qubits = m
        depht = p
        n = 3*n_qubits*(1+depht)
        target_vector, alpha = init_state_rsvg(n_qubits)
        params = random_params(n)
        device = get_device(n_qubits)


        @qml.qnode(device, interface="torch")
        def circuit(params, M=None):
            w = []
            aux = 0
            for j in range(n_qubits):
                qml.RX(params[j+aux], wires=j)
                qml.RY(params[j+1+aux], wires=j)
                qml.RZ(params[j+2+aux], wires=j)
                w.append(j)
                aux+=2
            for z in range(depht):
                for i in range(n_qubits-1):
                    qml.CNOT(wires=[i,i+1])
                for j in range(n_qubits):
                    qml.RX(params[j+aux], wires=j)
                    qml.RY(params[j+1+aux], wires=j)
                    qml.RZ(params[j+2+aux], wires=j)
                    aux+=2
            return qml.expval(qml.Hermitian(M, wires=w))
        best_params, f = train(50, circuit, params, alpha)
        x = np.linspace(0,len(f),len(f))
        plt.plot(x,f)
        plt.title('n_qubits = {} depht = {}'.format(n_qubits, depht))
        print('Fidelidade = ',fidelidade(circuit, best_params, alpha))
        plt.show()
#fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
#plt.show()
# Out:
# 49 1.232595164407831e-32
# Fidelidade =  0.9999999999999999
# 49 8.583068847654949e-06
# Fidelidade =  0.9941406250000002
# 49 0.0
# Fidelidade =  1.0
# 49 9.536743164064668e-07
# Fidelidade =  0.9990234374999999
# 49 0.0005044937133789112
# Fidelidade =  0.9755859374999999
# 49 0.0011682510375976638
# Fidelidade =  0.9941406249999999
# 49 0.00024414062500000347
# Fidelidade =  0.9882812499999999
# 49 0.000344276428222648
# Fidelidade =  0.9853515625000002
# 49 0.15642642974853516
# Fidelidade =  0.625
# 49 0.016366004943847656
# Fidelidade =  0.89453125
# 49 0.00018692016601561893
# Fidelidade =  0.9843750000000002
# 49 0.0006952285766601562
# Fidelidade =  0.974609375

# %%
n_qubits = 4
depht = n_qubits+1
#n = 3*n_qubits*(1+depht)
n = 3*n_qubits*(2+n_qubits)
target_vector, alpha = init_state_rsvg(n_qubits)
params = random_params(n)
device = get_device(n_qubits)
@qml.qnode(device, interface="torch")
def circuit(params, M=None):
    w = []
    aux = 0
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        w.append(j)
        aux+=2
    for z in range(depht):
        for i in range(n_qubits-1):
            qml.CNOT(wires=[i,i+1])
        for j in range(n_qubits):
            qml.RX(params[j+aux], wires=j)
            qml.RY(params[j+1+aux], wires=j)
            qml.RZ(params[j+2+aux], wires=j)
            aux+=2
    return qml.expval(qml.Hermitian(M, wires=w))
best_params, f = train(50, circuit, params, alpha)
x = np.linspace(0,len(f),len(f))
plt.plot(x,f)
plt.title('n_qubits = {} depht = {}'.format(n_qubits, depht))
print('Fidelidade = ',fidelidade(circuit, best_params, alpha))
plt.show()
# Out:
# 49 0.0021066665649414062
# Fidelidade =  0.9511718749999999

# %%
import pickle
with open('best_params(n_qubit=4 depth=4).pkl', 'wb') as g:
    pickle.dump(best_params, g)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute
from tools import *
import qiskit.quantum_info as qi
from qiskit.providers.aer import QasmSimulator


n_qubits = 4
depht = 0 # colocar n_qubits+1
n = 3*n_qubits*(1+depht)
target_vector, alpha = init_state_rsvg(n_qubits)
params = random_params(n)
params = params.detach().numpy()
device = get_device(n_qubits)
#best_params = # Obtido da função treino
#best_params = best_params.detach().numpy()

def qc_pos_train(params, M=None):
    w = []
    aux = 0
    qr = QuantumRegister(n_qubits)
    cr = ClassicalRegister(n_qubits)
    qc = QuantumCircuit(qr)#, cr)
    for j in range(n_qubits):
        qc.rx(params[j+aux], j)
        qc.ry(params[j+1+aux], j)
        qc.rz(params[j+2+aux], j)
        w.append(j)
        aux+=2
    for z in range(depht):
        for i in range(n_qubits-1):
            qc.cnot(i,i+1)
        for j in range(n_qubits):
            qc.rx(params[j+aux], j)
            qc.ry(params[j+1+aux], j)
            qc.rz(params[j+2+aux], j)
            aux+=2
    #qc.measure_all()
    return qc

qc = qc_pos_train(params)#,alpha)
#print(qc_pos_train(best_params,alpha))
stv1 = qi.Statevector.from_instruction(qc)
sim = QasmSimulator()
options = {'method': 'statevector'}
execute(qc, sim, backend_options=options)

print(stv1.probabilities)
#print(qc)
#qc.draw(output='mpl')

stv1.draw('latex')#, prefix='Statevector1:')
# Out:
# <bound method Statevector.probabilities of Statevector([ 0.10961279-0.34634731j,  0.05281984+0.11588052j,
#               0.34104226-0.24721765j, -0.03069149+0.14443793j,
#               0.08874576-0.2889372j ,  0.04476657+0.09603869j,
#               0.28199705-0.20809979j, -0.02451272+0.12038973j,
#               0.30358882-0.01816704j, -0.07474123+0.07603152j,
#               0.29549392+0.19245275j, -0.12210262+0.01931709j,
#               0.25245744-0.01726439j, -0.06164644+0.06378743j,
#               0.24721367+0.1580287j , -0.10145268+0.01693632j],
#             dims=(2, 2, 2, 2))>
# $$(0.109612786423 - 0.346347307156 i) |0000\rangle+ (0.052819838426 + 0.11588052189 i) |0001\rangle+ (0.341042264723 - 0.247217647437 i) |0010\rangle+ (-0.030691492291 + 0.144437927711 i) |0011\rangle+ (0.088745758187 - 0.288937203751 i) |0100\rangle+ (0.044766567966 + 0.09603869189 i) |0101\rangle + \ldots + (-0.122102617267 + 0.019317094569 i) |1011\rangle+ (0.252457436524 - 0.017264394816 i) |1100\rangle+ (-0.061646440097 + 0.063787434473 i) |1101\rangle+ (0.247213666708 + 0.15802869792 i) |1110\rangle+ (-0.101452678001 + 0.01693631955 i) |1111\rangle$$

# %%
n_qubits = 4
depht = 5
n = 3*n_qubits*(1+depht)
target_vector, alpha = init_state_rsvg(n_qubits)
params = random_params(n)
device = get_device(n_qubits)
@qml.qnode(device, interface="torch")
def circuit(params, M=None):
    w = []
    aux = 0
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        w.append(j)
        aux+=2
    for z in range(depht):
        for i in range(n_qubits-1):
            qml.CNOT(wires=[i,i+1])
        for j in range(n_qubits):
            qml.RX(params[j+aux], wires=j)
            qml.RY(params[j+1+aux], wires=j)
            qml.RZ(params[j+2+aux], wires=j)
            aux+=2
    return qml.expval(qml.Hermitian(M, wires=w))
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()

# %%
backend = QasmSimulator()
backend_options = {'method': 'statevector'}
job = execute(qc, backend, backend_options=backend_options)
job_result = job.result()
print(job_result.get_statevector(qc))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     313             return postprocess.format_statevector(
# --> 314                 self.data(experiment)["statevector"], decimals=decimals
#     315             )
#
# KeyError: 'statevector'
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# /tmp/ipykernel_9339/324046417.py in <module>
#       3 job = execute(qc, backend, backend_options=backend_options)
#       4 job_result = job.result()
# ----> 5 print(job_result.get_statevector(qc))
#
# ~/anaconda3/lib/python3.9/site-packages/qiskit/result/result.py in get_statevector(self, experiment, decimals)
#     315             )
#     316         except KeyError as ex:
# --> 317             raise QiskitError(f'No statevector for experiment "{repr(experiment)}"') from ex
#     318
#     319     def get_unitary(self, experiment=None, decimals=None):
#
# QiskitError: 'No statevector for experiment "<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fe452f73bb0>"'

# %%
device = get_device(n_qubits)

@qml.qnode(device, interface="torch")
def circuit_p(params, M=None):
    qml.Hadamard(wires=0)
    qml.RX(params[0], wires=0)
    qml.RY(params[1], wires=0)
    qml.RZ(params[2], wires=0)
    
    qml.Hadamard(wires=1)
    qml.RY(params[3], wires=1)
    qml.RZ(params[4], wires=1)
    qml.RX(params[5], wires=1)
    qml.CNOT(wires=[0,1])
    qml.RX(params[6], wires=0)
    qml.RY(params[7], wires=0)
    qml.RZ(params[8], wires=0)

    qml.RY(params[9], wires=1)
    qml.RZ(params[10], wires=1)
    qml.RX(params[11], wires=1)
    return  qml.probs(wires=[0,1])
counts = circuit_p(best_params, M=alpha)
print(counts)
prepared_state = counts.detach().numpy()**0.5
#print(target_vector)
print(alpha.detach().numpy())
print('------------------------')
print(prepared_state)
print(np.outer(prepared_state,prepared_state))
# Out:
# tensor([0.5234, 0.2725, 0.1670, 0.0371], dtype=torch.float64,
#        grad_fn=<SqueezeBackward0>)
# [[ 0.37626711+0.j         -0.15759332+0.08571461j  0.19346076+0.10156826j
#    0.10877248+0.02942129j]
#  [-0.15759332-0.08571461j  0.35566765+0.j         -0.04106124-0.03506653j
#    0.0588897 -0.02006553j]
#  [ 0.19346076-0.10156826j -0.04106124+0.03506653j  0.15286316+0.j
#    0.06808625-0.01383325j]
#  [ 0.10877248-0.02942129j  0.0588897 +0.02006553j  0.06808625+0.01383325j
#    0.11520208+0.j        ]]
# ------------------------
# [0.72348981 0.52197791 0.40864678 0.19263794]
# [[0.5234375  0.3776457  0.29565178 0.13937158]
#  [0.3776457  0.27246094 0.21330459 0.10055275]
#  [0.29565178 0.21330459 0.16699219 0.07872087]
#  [0.13937158 0.10055275 0.07872087 0.03710937]]

# %% [markdown]
# # Iniciando o estado aleatório com rsvg

# %%
from tools import *
n_qubits = 2
depht = 0
#n = 3*n_qubits+depht*n_qubits*3
n = 3*n_qubits*(1+depht)
#alpha = init_state_rdm_ginibre(n_qubits)
target_vector, alpha = init_state_rsvg(n_qubits)

params = random_params(n)
print(np.shape(params))
device = get_device(n_qubits)

@qml.qnode(device, interface="torch")
def circuit(params, M=None):
    #n_qubits = 5
    #depht = 10
    #n = 6*n_qubits
    w = []

    aux = 0
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        #qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        w.append(j)
        aux+=2
    
    for z in range(depht):
        #print(z)
        for i in range(n_qubits-1):
            qml.CNOT(wires=[i,i+1])
        for j in range(n_qubits):
            qml.RX(params[j+aux], wires=j)
            #qml.RY(params[j+1+aux], wires=j)
            qml.RZ(params[j+2+aux], wires=j)
            aux+=2
        #for j in range(n_qubits):
        #    qml.RX(params[j+aux], wires=j)
        #    qml.RY(params[j+1+aux], wires=j)
        #    qml.RZ(params[j+2+aux], wires=j)
        #    aux+=2
        #for i in range(n_qubits-1):
        #    qml.CNOT(wires=[i,i+1])
        #for j in range(n_qubits):
        #    qml.RX(params[j+aux], wires=j)
        #    qml.RY(params[j+1+aux], wires=j)
        #    qml.RZ(params[j+2+aux], wires=j)
        #    aux+=2
    return qml.expval(qml.Hermitian(M, wires=w))
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()
# Out:
# torch.Size([6])

# %%
best_params, f = train(50, circuit, params, alpha)
x = np.linspace(0,len(f),len(f))
plt.plot(x,f)
plt.show()
# Out:
# 49 0.015140533447265625

# %%
from tools import *
n_qubits = 4
depht = 5
#n = 3*n_qubits+depht*n_qubits*3
n_params = 3*n_qubits*(1+depht)
#alpha = init_state_rdm_ginibre(n_qubits)
target_vector, alpha = init_state_rsvg(n_qubits)

params = random_params(n)
#print(np.shape(params))
device = get_device(n_qubits)

@qml.qnode(device, interface="torch")
def circuit(params, M=None):
    #n_qubits = 5
    #depht = 10
    #n = 6*n_qubits
    w = []

    aux = 0
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        w.append(j)
        aux+=2
    
    for z in range(depht):
        for i in range(n_qubits-1):
            qml.CNOT(wires=[i,i+1])
        for j in range(n_qubits):
            qml.RX(params[j+aux], wires=j)
            qml.RY(params[j+1+aux], wires=j)
            qml.RZ(params[j+2+aux], wires=j)
            aux+=2
        #for j in range(n_qubits):
        #    qml.RX(params[j+aux], wires=j)
        #    qml.RY(params[j+1+aux], wires=j)
        #    qml.RZ(params[j+2+aux], wires=j)
        #    aux+=2
        #for i in range(n_qubits-1):
        #    qml.CNOT(wires=[i,i+1])
        #for j in range(n_qubits):
        #    qml.RX(params[j+aux], wires=j)
        #    qml.RY(params[j+1+aux], wires=j)
        #    qml.RZ(params[j+2+aux], wires=j)
        #    aux+=2
    return qml.expval(qml.Hermitian(M, wires=w))
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()

# %%
best_params, f = train(400, circuit, params, alpha)
x = np.linspace(0,len(f),len(f))
plt.plot(x,f)
plt.show()
# Out:
# 0 0.98443603515625
# 1 0.7622108459472656
# 2 0.46596622467041016
# 3 0.3001413345336914
# 4 0.15106582641601562
# 5 0.11154556274414062
# 6 0.0753030776977539
# 7 0.0726470947265625
# 8 0.058182716369628906
# 9 0.06798648834228516
# 10 0.0700387954711914
# 11 0.052666664123535156
# 12 0.050889015197753906
# 13 0.031937599182128906
# 14 0.019501686096191406
# 15 0.024109840393066406
# 16 0.016117095947265625
# 17 0.013278961181640625
# 18 0.0166168212890625
# 19 0.011539459228515625
# 20 0.012612342834472656
# 21 0.007218360900878906
# 22 0.005082130432128906
# 23 0.005364418029785156
# 24 0.006569862365722656
# 25 0.004029273986816406
# 26 0.005654335021972656
# 27 0.0025787353515625
# 28 0.0030984878540039062
# 29 0.0012359619140625
# 30 0.00152587890625
# 31 0.0012359619140625
# 32 0.0011682510375976562
# 33 0.0005960464477539062
# 34 0.001377105712890625
# 35 0.0012359619140625
# 36 0.0018463134765625
# 37 0.0010385513305664062
# 38 0.001102447509765625
# 39 0.0013055801391601562
# 40 0.001102447509765625
# 41 0.0009164810180664062
# 42 0.000644683837890625
# 43 0.000461578369140625
# 44 0.00054931640625
# 45 0.0003814697265625
# 46 0.0003814697265625
# 47 0.0003814697265625
# 48 0.000244140625
# 49 0.000244140625
# 50 7.724761962890625e-05
# 51 9.5367431640625e-05
# 52 0.000308990478515625
# 53 0.000186920166015625
# 54 0.00034427642822265625
# 55 9.5367431640625e-05
# 56 7.724761962890625e-05
# 57 2.384185791015625e-05
# 58 6.103515625e-05
# 59 9.5367431640625e-05
# 60 0.0001373291015625
# 61 0.00011539459228515625
# 62 6.103515625e-05
# 63 2.384185791015625e-05
# 64 6.103515625e-05
# 65 2.384185791015625e-05
# 66 2.384185791015625e-05
# 67 6.103515625e-05
# 68 0.00016117095947265625
# 69 1.52587890625e-05
# 70 4.673004150390625e-05
# 71 9.5367431640625e-07
# 72 0.0
# 73 1.52587890625e-05
# 74 1.52587890625e-05
# 75 3.4332275390625e-05
# 76 3.4332275390625e-05
# 77 1.52587890625e-05
# 78 3.814697265625e-06
# 79 3.814697265625e-06
# 80 3.814697265625e-06
# 81 8.58306884765625e-06
# 82 9.5367431640625e-07
# 83 8.58306884765625e-06
# 84 1.52587890625e-05
# 85 8.58306884765625e-06
# 86 2.384185791015625e-05
# 87 3.814697265625e-06
# 88 0.0
# 89 0.0
# 90 1.52587890625e-05
# 91 3.814697265625e-06
# 92 8.58306884765625e-06
# 93 3.814697265625e-06
# 94 1.52587890625e-05
# 95 8.58306884765625e-06
# 96 8.58306884765625e-06
# 97 1.52587890625e-05
# 98 3.814697265625e-06
# 99 8.58306884765625e-06
# 100 8.58306884765625e-06
# 101 3.814697265625e-06
# 102 0.0
# 103 0.0
# 104 9.5367431640625e-07
# 105 9.5367431640625e-07
# 106 9.5367431640625e-07
# 107 9.5367431640625e-07
# 108 9.5367431640625e-07
# 109 1.52587890625e-05
# 110 8.58306884765625e-06
# 111 8.58306884765625e-06
# 112 3.814697265625e-06
# 113 9.5367431640625e-07
# 114 8.58306884765625e-06
# 115 9.5367431640625e-07
# 116 9.5367431640625e-07
# 117 9.5367431640625e-07
# 118 9.5367431640625e-07
# 119 1.52587890625e-05
# 120 9.5367431640625e-07
# 121 3.814697265625e-06
# 122 3.814697265625e-06
# 123 3.814697265625e-06
# 124 3.814697265625e-06
# 125 0.0
# 126 9.5367431640625e-07
# 127 3.814697265625e-06
# 128 0.0
# 129 8.58306884765625e-06
# 130 9.5367431640625e-07
# 131 1.52587890625e-05
# 132 9.5367431640625e-07
# 133 3.814697265625e-06
# 134 3.814697265625e-06
# 135 9.5367431640625e-07
# 136 3.814697265625e-06
# 137 0.0
# 138 8.58306884765625e-06
# 139 8.58306884765625e-06
# 140 0.0
# 141 9.5367431640625e-07
# 142 1.52587890625e-05
# 143 9.5367431640625e-07
# 144 0.0
# 145 9.5367431640625e-07
# 146 0.0
# 147 0.0
# 148 9.5367431640625e-07
# 149 0.0
# 150 9.5367431640625e-07
# 151 3.814697265625e-06
# 152 0.0
# 153 0.0
# 154 0.0
# 155 9.5367431640625e-07
# 156 1.52587890625e-05
# 157 0.0
# 158 9.5367431640625e-07
# 159 9.5367431640625e-07
# 160 3.814697265625e-06
# 161 3.814697265625e-06
# 162 0.0
# 163 9.5367431640625e-07
# 164 9.5367431640625e-07
# 165 0.0
# 166 9.5367431640625e-07
# 167 8.58306884765625e-06
# 168 3.814697265625e-06
# 169 9.5367431640625e-07
# 170 9.5367431640625e-07
# 171 9.5367431640625e-07
# 172 9.5367431640625e-07
# 173 0.0
# 174 0.0
# 175 9.5367431640625e-07
# 176 9.5367431640625e-07
# 177 0.0
# 178 0.0
# 179 0.0
# 180 0.0
# 181 0.0
# 182 3.814697265625e-06
# 183 3.814697265625e-06
# 184 0.0
# 185 8.58306884765625e-06
# 186 0.0
# 187 3.814697265625e-06
# 188 0.0
# 189 9.5367431640625e-07
# 190 9.5367431640625e-07
# 191 3.814697265625e-06
# 192 9.5367431640625e-07
# 193 9.5367431640625e-07
# 194 1.52587890625e-05
# 195 3.814697265625e-06
# 196 9.5367431640625e-07
# 197 3.814697265625e-06
# 198 3.814697265625e-06
# 199 9.5367431640625e-07
# 200 9.5367431640625e-07
# 201 9.5367431640625e-07
# 202 0.0
# 203 9.5367431640625e-07
# 204 8.58306884765625e-06
# 205 0.0
# 206 9.5367431640625e-07
# 207 8.58306884765625e-06
# 208 9.5367431640625e-07
# 209 0.0
# 210 9.5367431640625e-07
# 211 0.0
# 212 9.5367431640625e-07
# 213 9.5367431640625e-07
# 214 3.814697265625e-06
# 215 0.0
# 216 9.5367431640625e-07
# 217 0.0
# 218 0.0
# 219 9.5367431640625e-07
# 220 9.5367431640625e-07
# 221 3.814697265625e-06
# 222 9.5367431640625e-07
# 223 3.814697265625e-06
# 224 8.58306884765625e-06
# 225 9.5367431640625e-07
# 226 0.0
# 227 0.0
# 228 9.5367431640625e-07
# 229 9.5367431640625e-07
# 230 0.0
# 231 0.0
# 232 3.814697265625e-06
# 233 3.814697265625e-06
# 234 9.5367431640625e-07
# 235 0.0
# 236 0.0
# 237 9.5367431640625e-07
# 238 3.814697265625e-06
# 239 0.0
# 240 0.0
# 241 3.814697265625e-06
# 242 9.5367431640625e-07
# 243 9.5367431640625e-07
# 244 8.58306884765625e-06
# 245 3.814697265625e-06
# 246 9.5367431640625e-07
# 247 0.0
# 248 0.0
# 249 9.5367431640625e-07
# 250 3.814697265625e-06
# 251 3.814697265625e-06
# 252 0.0
# 253 9.5367431640625e-07
# 254 9.5367431640625e-07
# 255 0.0
# 256 3.814697265625e-06
# 257 0.0
# 258 0.0
# 259 9.5367431640625e-07
# 260 8.58306884765625e-06
# 261 0.0
# 262 0.0
# 263 9.5367431640625e-07
# 264 9.5367431640625e-07
# 265 0.0
# 266 0.0
# 267 8.58306884765625e-06
# 268 9.5367431640625e-07
# 269 3.814697265625e-06
# 270 0.0
# 271 9.5367431640625e-07
# 272 0.0
# 273 0.0
# 274 9.5367431640625e-07
# 275 0.0
# 276 3.814697265625e-06
# 277 0.0
# 278 0.0
# 279 3.814697265625e-06
# 280 0.0
# 281 9.5367431640625e-07
# 282 1.52587890625e-05
# 283 0.0
# 284 9.5367431640625e-07
# 285 0.0
# 286 9.5367431640625e-07
# 287 9.5367431640625e-07
# 288 0.0
# 289 0.0
# 290 0.0
# 291 9.5367431640625e-07
# 292 0.0
# 293 0.0
# 294 8.58306884765625e-06
# 295 9.5367431640625e-07
# 296 0.0
# 297 9.5367431640625e-07
# 298 9.5367431640625e-07
# 299 3.814697265625e-06
# 300 9.5367431640625e-07
# 301 9.5367431640625e-07
# 302 3.814697265625e-06
# 303 3.814697265625e-06
# 304 0.0
# 305 0.0
# 306 0.0
# 307 9.5367431640625e-07
# 308 9.5367431640625e-07
# 309 0.0
# 310 0.0
# 311 0.0
# 312 9.5367431640625e-07
# 313 0.0
# 314 9.5367431640625e-07
# 315 9.5367431640625e-07
# 316 8.58306884765625e-06
# 317 0.0
# 318 0.0
# 319 9.5367431640625e-07
# 320 0.0
# 321 9.5367431640625e-07
# 322 3.814697265625e-06
# 323 0.0
# 324 9.5367431640625e-07
# 325 9.5367431640625e-07
# 326 0.0
# 327 0.0
# 328 0.0
# 329 0.0
# 330 3.814697265625e-06
# 331 0.0
# 332 0.0
# 333 0.0
# 334 9.5367431640625e-07
# 335 0.0
# 336 0.0
# 337 0.0
# 338 0.0
# 339 9.5367431640625e-07
# 340 0.0
# 341 9.5367431640625e-07
# 342 9.5367431640625e-07
# 343 0.0
# 344 9.5367431640625e-07
# 345 0.0
# 346 0.0
# 347 0.0
# 348 0.0
# 349 0.0
# 350 9.5367431640625e-07
# 351 3.814697265625e-06
# 352 0.0
# 353 0.0
# 354 0.0
# 355 9.5367431640625e-07
# 356 0.0
# 357 9.5367431640625e-07
# 358 0.0
# 359 0.0
# 360 0.0
# 361 3.814697265625e-06
# 362 9.5367431640625e-07
# 363 0.0
# 364 0.0
# 365 9.5367431640625e-07
# 366 9.5367431640625e-07
# 367 9.5367431640625e-07
# 368 0.0
# 369 0.0
# 370 9.5367431640625e-07
# 371 3.814697265625e-06
# 372 0.0
# 373 0.0
# 374 9.5367431640625e-07
# 375 9.5367431640625e-07
# 376 9.5367431640625e-07
# 377 9.5367431640625e-07
# 378 3.814697265625e-06
# 379 0.0
# 380 9.5367431640625e-07
# 381 0.0
# 382 3.814697265625e-06
# 383 8.58306884765625e-06
# 384 0.0
# 385 0.0
# 386 3.814697265625e-06
# 387 9.5367431640625e-07
# 388 9.5367431640625e-07
# 389 9.5367431640625e-07
# 390 9.5367431640625e-07
# 391 0.0
# 392 9.5367431640625e-07
# 393 0.0
# 394 9.5367431640625e-07
# 395 0.0
# 396 0.0
# 397 9.5367431640625e-07
# 398 0.0
# 399 8.58306884765625e-06

# %%
import pickle
with open('best_params.pkl', 'wb') as g:
    pickle.dump(best_params, g)

# %%
print('Fidelidade = ',fidelidade(circuit, best_params, alpha))
# Out:
# Fidelidade =  0.9990234375

# %%
n_qubits = 2
n = 6*n_qubits
target_vector, alpha = init_state_rsvg(n_qubits)

params = random_params(n)
device = get_device(n_qubits)

@qml.qnode(device, interface="torch")
def circuit(params, M=None):
    qml.Hadamard(wires=0)
    qml.RX(params[0], wires=0)
    qml.RY(params[1], wires=0)
    qml.RZ(params[2], wires=0)
    
    qml.Hadamard(wires=1)
    qml.RY(params[3], wires=1)
    qml.RZ(params[4], wires=1)
    qml.RX(params[5], wires=1)
    qml.CNOT(wires=[0,1])
    qml.RX(params[6], wires=0)
    qml.RY(params[7], wires=0)
    qml.RZ(params[8], wires=0)

    qml.RY(params[9], wires=1)
    qml.RZ(params[10], wires=1)
    qml.RX(params[11], wires=1)
    return qml.expval(qml.Hermitian(M, wires=[0,1]))
#drawer = qml.draw(circuit)
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()

# %%
best_params, f = train(100, circuit, params, alpha)
x = np.linspace(0,len(f),len(f))
plt.plot(x,f)
plt.show()
# Out:
# 0 0.7004251480102539
# 1 0.46596622467041016
# 2 0.289536476135254
# 3 0.20092105865478527
# 4 0.08640384674072273
# 5 0.03552341461181645
# 6 0.021457672119140656
# 7 0.00807189941406252
# 8 0.004807472229003922
# 9 0.007053375244140644
# 10 0.008248329162597677
# 11 0.013962745666503932
# 12 0.016869544982910184
# 13 0.02088928222656253
# 14 0.018959999084472687
# 15 0.021457672119140656
# 16 0.01869201660156253
# 17 0.013732910156250026
# 18 0.014663696289062528
# 19 0.011962890625000024
# 20 0.009922027587890648
# 21 0.008426666259765646
# 22 0.00878906250000002
# 23 0.007385253906250019
# 24 0.009922027587890648
# 25 0.0065698623657226745
# 26 0.004943847656250016
# 27 0.004540443420410171
# 28 0.004807472229003922
# 29 0.0035486221313476697
# 30 0.0021066665649414167
# 31 0.0025787353515625113
# 32 0.001931190490722666
# 33 0.0025787353515625113
# 34 0.002017974853515635
# 35 0.0015258789062500087
# 36 0.0010385513305664134
# 37 0.000916481018066413
# 38 0.0007476806640625061
# 39 0.00034427642822266037
# 40 0.00034427642822266037
# 41 0.00034427642822266037
# 42 0.00046157836914062977
# 43 0.00034427642822266037
# 44 0.00016117095947265907
# 45 0.00024414062500000347
# 46 0.0001373291015625026
# 47 0.0004205703735351608
# 48 0.0002145767211914095
# 49 0.0002145767211914095
# 50 0.00024414062500000347
# 51 0.00016117095947265907
# 52 0.00016117095947265907
# 53 6.103515625000173e-05
# 54 0.00027561187744140994
# 55 7.72476196289082e-05
# 56 6.103515625000173e-05
# 57 7.72476196289082e-05
# 58 4.673004150390777e-05
# 59 0.0001373291015625026
# 60 4.673004150390777e-05
# 61 4.673004150390777e-05
# 62 2.3841857910157334e-05
# 63 6.103515625000173e-05
# 64 2.3841857910157334e-05
# 65 1.5258789062500867e-05
# 66 3.814697265625434e-06
# 67 3.43322753906263e-05
# 68 3.43322753906263e-05
# 69 1.5258789062500867e-05
# 70 8.5830688476569e-06
# 71 8.5830688476569e-06
# 72 1.5258789062500867e-05
# 73 2.3841857910157334e-05
# 74 1.5258789062500867e-05
# 75 3.43322753906263e-05
# 76 9.536743164064668e-07
# 77 2.3841857910157334e-05
# 78 1.5258789062500867e-05
# 79 3.814697265625434e-06
# 80 8.5830688476569e-06
# 81 8.5830688476569e-06
# 82 3.814697265625434e-06
# 83 1.5258789062500867e-05
# 84 8.5830688476569e-06
# 85 3.814697265625434e-06
# 86 8.5830688476569e-06
# 87 3.814697265625434e-06
# 88 2.3841857910157334e-05
# 89 9.536743164064668e-07
# 90 1.232595164407831e-32
# 91 1.5258789062500867e-05
# 92 4.673004150390777e-05
# 93 8.5830688476569e-06
# 94 2.3841857910157334e-05
# 95 8.5830688476569e-06
# 96 9.536743164064668e-07
# 97 3.814697265625434e-06
# 98 3.814697265625434e-06
# 99 9.536743164064668e-07

# %%
print('Fidelidade = ',fidelidade(circuit, best_params, alpha))
# Out:
# Fidelidade =  0.9951171874999999

# %%
device = get_device(n_qubits)

@qml.qnode(device, interface="torch")
def circuit_p(params, M=None):
    qml.Hadamard(wires=0)
    qml.RX(params[0], wires=0)
    qml.RY(params[1], wires=0)
    qml.RZ(params[2], wires=0)
    
    qml.Hadamard(wires=1)
    qml.RY(params[3], wires=1)
    qml.RZ(params[4], wires=1)
    qml.RX(params[5], wires=1)
    qml.CNOT(wires=[0,1])
    qml.RX(params[6], wires=0)
    qml.RY(params[7], wires=0)
    qml.RZ(params[8], wires=0)

    qml.RY(params[9], wires=1)
    qml.RZ(params[10], wires=1)
    qml.RX(params[11], wires=1)
    return  qml.probs(wires=[0,1])
counts = circuit_p(best_params, M=alpha)
print(counts)
prepared_state = counts.detach().numpy()**0.5
print(target_vector)
print(alpha.detach().numpy())
print('------------------------')
print(prepared_state)
print(np.outer(prepared_state,prepared_state))
# Out:
# tensor([0.1953, 0.0859, 0.4443, 0.2744], dtype=torch.float64,
#        grad_fn=<SqueezeBackward0>)
# [-0.10418639+0.44250651j -0.13166609-0.18125312j  0.04999019+0.65957495j
#  -0.45022131-0.32079148j]
# [[ 0.20666682+0.j         -0.06648787+0.07714721j  0.28665791-0.09083972j
#   -0.09504539+0.23264797j]
#  [-0.06648787-0.07714721j  0.05018865+0.j         -0.12613203-0.07778277j
#    0.11742333-0.03936666j]
#  [ 0.28665791+0.09083972j -0.12613203+0.07778277j  0.43753813+0.j
#   -0.23409267+0.28091827j]
#  [-0.09504539-0.23264797j  0.11742333+0.03936666j -0.23409267-0.28091827j
#    0.3056064 +0.j        ]]
# ------------------------
# [0.44194174 0.29315098 0.66658528 0.52384546]
# [[0.1953125  0.12955566 0.29459186 0.23150917]
#  [0.12955566 0.0859375  0.19541013 0.15356581]
#  [0.29459186 0.19541013 0.44433594 0.34918767]
#  [0.23150917 0.15356581 0.34918767 0.27441406]]

# %%
n_qubits = 4
n = 6*n_qubits
#alpha = init_state_rdm_ginibre(n_qubits)
target_vector, alpha = init_state_rsvg(n_qubits)

params = random_params(n+24)
device = get_device(n_qubits)

@qml.qnode(device, interface="torch")
def circuit(params, M=None):
    #n_qubits = 5
    n = 6*n_qubits
    w = []

    for i in range(n_qubits):
    #    qml.Hadamard(wires=i)
        w.append(i)

    aux = 0
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        aux+=2
    for i in range(n_qubits-1):
        qml.CNOT(wires=[i,i+1])
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        aux+=2
    for i in range(n_qubits-1):
        qml.CNOT(wires=[i,i+1])
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        aux+=2
    for i in range(n_qubits-1):
        qml.CNOT(wires=[i,i+1])
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        aux+=2
    return qml.expval(qml.Hermitian(M, wires=w))
fig, ax = qml.draw_mpl(circuit, decimals=2)(params, alpha)
plt.show()

# %%
best_params, f = train(50, circuit, params, alpha)
x = np.linspace(0,len(f),len(f))
plt.plot(x,f)
plt.show()
# Out:
# 0 0.9441614151000977
# 1 0.7862701416015627
# 2 0.6428155899047855
# 3 0.5876779556274417
# 4 0.4566802978515628
# 5 0.3120269775390629
# 6 0.22711181640625042
# 7 0.15106582641601596
# 8 0.16424655914306677
# 9 0.19397830963134804
# 10 0.18045902252197304
# 11 0.18212223052978554
# 12 0.16903018951416052
# 13 0.1326837539672855
# 14 0.10011291503906278
# 15 0.08412265777587917
# 16 0.0964393615722659
# 17 0.06952285766601586
# 18 0.05088901519775411
# 19 0.042057037353515805
# 20 0.031243324279785312
# 21 0.028542518615722805
# 22 0.03406620025634782
# 23 0.04165744781494159
# 24 0.027886390686035305
# 25 0.023208618164062635
# 26 0.02350711822509779
# 27 0.02261734008789076
# 28 0.017380714416504024
# 29 0.010514259338378998
# 30 0.0128326416015626
# 31 0.008248329162597738
# 32 0.006103515625000069
# 33 0.007724761962890703
# 34 0.005222320556640689
# 35 0.007724761962890703
# 36 0.005951881408691475
# 37 0.005802154541015693
# 38 0.00807189941406258
# 39 0.003785133361816461
# 40 0.005654335021972723
# 41 0.00508213043212897
# 42 0.004281044006347714
# 43 0.004807472229003968
# 44 0.0039062500000000555
# 45 0.003433227539062552
# 46 0.003785133361816461
# 47 0.002884864807128954
# 48 0.0024805068969727005
# 49 0.0022897720336914488

# %%
print('Fidelidade = ',fidelidade(circuit, best_params, alpha))
# Out:
# Fidelidade =  0.9628906249999996

# %%
n_qubits = 5
device = get_device(n_qubits)

@qml.qnode(device, interface="torch")
def circuit_p(params, M=None):
    #n_qubits = 5
    n = 6*n_qubits
    w = []

    for i in range(n_qubits):
        qml.Hadamard(wires=i)
        w.append(i)

    aux = 0
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        aux+=2
    for i in range(n_qubits-1):
        qml.CNOT(wires=[i,i+1])
    for j in range(n_qubits):
        qml.RX(params[j+aux], wires=j)
        qml.RY(params[j+1+aux], wires=j)
        qml.RZ(params[j+2+aux], wires=j)
        aux+=2
    
    return  qml.probs(wires=w)

counts = circuit_p(best_params, M=alpha)
print(counts)
prepared_state = counts.detach().numpy()**0.5
print(target_vector)
print(alpha.detach().numpy())
print('------------------------')
print(prepared_state)
print(np.outer(prepared_state,prepared_state))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_5146/3741512154.py in <module>
#      28     return  qml.probs(wires=w)
#      29
# ---> 30 counts = circuit_p(best_params, M=alpha)
#      31 print(counts)
#      32 prepared_state = counts.detach().numpy()**0.5
#
# ~/anaconda3/lib/python3.9/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     616
#     617         # construct the tape
# --> 618         self.construct(args, kwargs)
#     619
#     620         cache = self.execute_kwargs.get("cache", False)
#
# ~/anaconda3/lib/python3.9/site-packages/pennylane/qnode.py in construct(self, args, kwargs)
#     526
#     527         with self.tape:
# --> 528             self._qfunc_output = self.func(*args, **kwargs)
#     529         self._tape._qfunc_output = self._qfunc_output
#     530
#
# /tmp/ipykernel_5146/3741512154.py in circuit_p(params, M)
#      23         qml.RX(params[j+aux], wires=j)
#      24         qml.RY(params[j+1+aux], wires=j)
# ---> 25         qml.RZ(params[j+2+aux], wires=j)
#      26         aux+=2
#      27
#
# IndexError: index 18 is out of bounds for dimension 0 with size 18
